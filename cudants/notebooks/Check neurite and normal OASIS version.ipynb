# %%
import nibabel as nib
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: <object object at 0x7f03eea57460>
# Populating the interactive namespace from numpy and matplotlib

# %%
img1 = nib.load("/data/rohitrango/OASIS/imagesTr/OASIS_0001_0000.nii.gz").get_fdata()
img1 = (img1.transpose(0, 2, 1))[::-1, ::-1]

# %%
img2 = nib.load("/mnt/rohit_data2/neurite-OASIS/OASIS_OAS1_0001_MR1/aligned_norm.nii.gz").get_fdata()

# %%
print(img1.shape, img2.shape)
# Out:
# (160, 192, 224) (160, 192, 224)

# %%
for i in range(8):
    i1, i2, i3 = i//4, (i//2)%2, i%2
    i1, i2, i3 = 2*i1-1, 2*i2-1, 2*i3-1
    img1c = img1[::i1, ::i2, ::i3] + 0
    print(np.abs(img1c - img2).mean(), i1, i2, i3)
# Out:
# 0.05518470466587224 -1 -1 -1
# 0.04337151231949807 -1 -1 1
# 0.04555345482596636 -1 1 -1
# 0.01869400989045803 -1 1 1
# 0.05517362146286473 1 -1 -1
# 0.042860724984070064 1 -1 1
# 0.045323529521709274 1 1 -1
# 0.0 1 1 1

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
ax1.imshow(img1[..., 112], 'gray'); ax1.axis('off');
ax2.imshow(img2[..., 112], 'gray'); ax1.axis('off');

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
ax1.imshow(img1[80], 'gray'); ax1.axis('off');
ax2.imshow(img2[80], 'gray'); ax1.axis('off'); 
print(np.abs(img1[80] - img2[80]).max())
# Out:
# 0.0

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
ax1.imshow(img1[:, 90], 'gray'); ax1.axis('off');
ax2.imshow(img2[:, 90], 'gray'); ax1.axis('off');
